# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('../src')

import control_spoiler

# %%
review = """La película sigue a un grupo de astronautas que 
viajan a Marte 
en una misión de rescate. El capitán Torres lidera al equipo 
a través
de tormentas solares y fallos en el sistema de navegación. Al 
llegar
a Marte descubren que la base está abandonada y los 
suministros
destruidos. Torres decide sacrificar la nave nodriza para 
salvar
al equipo y logran volver a la Tierra en una cápsula de 
emergencia.
El final revela que Torres sobrevivió gracias a un pasaje 
secreto."""

lista = [input("Ingrese palabras (separadas por coma)")]
print(control_spoiler.filtro(review,lista))
# Out:
# La película sigue a un grupo ** *********** que
# viajan a *****
# en una misión ** rescate. El capitán ****** lidera al equipo
# a través
# de tormentas solares * fallos en el ******* ** navegación. Al
# llegar
# a ***** descubren que la base está ********** * los
# suministros
# destruidos. ****** decide ********** la **** ******* para
# salvar
# al equipo * logran volver a la ****** en una cápsula **
# emergencia.
# El ***** revela que ****** ********** gracias a un pasaje
# secreto.
