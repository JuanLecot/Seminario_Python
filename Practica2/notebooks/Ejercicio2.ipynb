# %%
import sys 
sys.path.append('../src')

import analisis_playlist

# %%
playlist = [
    {"title": "Bohemian Rhapsody", "duration": "5:55"},
    {"title": "Hotel California", "duration": "6:30"},
    {"title": "Stairway to Heaven", "duration": "8:02"},
    {"title": "Imagine", "duration": "3:07"},
    {"title": "Smells Like Teen Spirit", "duration": "5:01"},
    {"title": "Billie Jean", "duration": "4:54"},
    {"title": "Hey Jude", "duration": "7:11"},
    {"title": "Like a Rolling Stone", "duration": "6:13"}
]

total_duration = analisis_playlist.obtener_duracion_playlist(playlist)
max_duration = (analisis_playlist.obtener_maximo(playlist))
min_duration = (analisis_playlist.obtener_minimo(playlist))

print (f"Duracion Total: {total_duration}")
print (f"Cancion más larga: {max_duration[1]} ({max_duration[0]})")
print (f"Cancion más corta: {min_duration[1]} ({min_duration[0]})")
# Out:
# Duracion Total: 46.53
# Cancion más larga: Stairway to Heaven (8.02)
# Cancion más corta: Imagine (3.07)
