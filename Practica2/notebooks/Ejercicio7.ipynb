# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys 
sys.path.append('../src')

import sorteo_amigo

# %%
lista_nombres= input("Ingrese nombres del sorteo (separados por coma y al menos 3)")

sorteo = sorteo_amigo.realizar_sorteo(lista_nombres)

print("Sorteo de amigo invisible:")
for elem in sorteo:
    print (f"{elem[0]} -> {elem[1]}")
# Out:
# Sorteo de amigo invisible:
# Ana -> Mateo
# Pedro -> Lucia
# Lucia -> Sofia
# Mateo -> Ana
# Sofia -> Pedro
