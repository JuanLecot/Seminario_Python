# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('../src')

import validacion_mail

# %%
mail = input("Ingrese un mail: ")
valido = validacion_mail.validar(mail)

if valido == True:
    print ("El mail es válido.")
else:
    print ("El mail es inválido.")
# Out:
# El mail es válido.
