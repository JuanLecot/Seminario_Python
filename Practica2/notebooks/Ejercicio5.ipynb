# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys 
sys.path.append('../src')

import costo_envio

# %%
peso_paquete = float(input("Ingrese el peso del paquete: "))
zona_destino = input("Ingrese zona de envio (local/regional/nacional): ")

costo_total = costo_envio.calcular_costo(peso_paquete,zona_destino)

if (type(costo_total)== str ):
    print(costo_total)
else:
    print (f"Costo de envío: ${costo_total}")
# Out:
# Zona no válida. Las zonas disponibles son: local, regional, nacional.
